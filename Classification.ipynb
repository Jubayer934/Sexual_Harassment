# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Path to the zip file in Drive
zip_path = "/content/drive/MyDrive/ModelTrain/Sexual_Harassment/dataset/DS.zip"

# Unzip it to /content/
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/Sexual_Harassment_Dataset")

# Set dataset path
dataset_path = "/content/Sexual_Harassment_Dataset"

# %%
# Optional: Save output video
print("Saving labeled video to 'labeled_output.mp4'...")
h, w = processed_frames[0].shape[:2]
out = cv2.VideoWriter("labeled_output.mp4", cv2.VideoWriter_fourcc(*"mp4v"), 30, (w, h))

for f in processed_frames:
    out.write(f)
out.release()
print("Saved successfully.")

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = '/content/labeled_output.mp4' # Replace with your video file path

# Read the video file and encode it
mp4 = open(video_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# Display the video
HTML(f"""
<video width=400 controls>
    <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# <video width=400 controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
